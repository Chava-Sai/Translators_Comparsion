# %% [markdown]
# <a href="https://colab.research.google.com/github/Chava-Sai/Translators_Comparsion/blob/main/Google_Translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Google Translator

# %%
# !pip install --upgrade googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 10.8 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=fbefc6b2e74f9180eeb9559a252103f1edebe046d2b6d477479819ec82d1ab5e
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
from googletrans import Translator
import pandas as pd
from tqdm import tqdm

def translate_text(text, src_lang='hi', dest_lang='en'):
    translator = Translator()
    translation = translator.translate(text, src=src_lang, dest=dest_lang)
    return translation.text

# Assuming you have an Excel file with a sheet named 'Sheet1' and a column named 'hindi'
# Replace 'your_dataset.xlsx' with the actual file path or Excel file
# df = pd.read_excel('', sheet_name='Sheet1')
df = pd.read_excel('Final_AI_Pro_Output.xlsx')
df = df.head(1000)

# Create a tqdm progress bar for the translation process
tqdm.pandas()

# Apply translation to each row in the 'hindi' column with tqdm
df['eng_trans'] = df['hindi'].progress_apply(translate_text)

# Save the translated DataFrame to a new Excel file
df.to_excel('Google_Trans.xlsx', index=False, sheet_name='Sheet1')
# Out:
# 100%|██████████| 1000/1000 [10:19<00:00,  1.61it/s]

# %%
df.head(5)
# Out:
#                                                hindi  \
# 0                        और चीजों के दूसरे पक्ष पर,
# 1                   अगर आप एक वस्तु रखना चाहते हैं,
# 2  आप इसे करने के लिए एक ताकत लगाने रखने के लिए क...
# 3   हम हमारे रोजमर्रा के अनुभव में कभी नहीं किया है
# 4                  एक वस्तु है कि बस चलती रहती देखा
#
#                                     english  \
# 0          And on the other side of things,
# 1     if you want to keep an object moving,
# 2  you have to keep applying a force to it.
# 3   We 've never in our everyday experience
# 4     seen an object that just keeps moving
#
#                                           eng_trans
# 0                  And on the other side of things,
# 1                    If you want to keep an object,
# 2             You have to keep a strength to do it.
# 3     We have never done in our everyday experience
# 4  There is an object that just saw the bus walking
